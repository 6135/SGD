# %% [markdown]
# <h1>Tem Diabetes?</h1>
#
# <h1>Class= Tem Diabetes</h1>
#
# <h2>Objectivo:</h2>
#
#
# Usando um conjunto de dados de Diabetes, prever se uma pessoa terá diabetes ou não usando caracteristicas medidas.
#
# <h2>Dados</h2>
#
# Número total de casos:768, 8 variáveis de entrada, uma variável de saída
# 0= não tem diabetes : 500
# 1=tem diabetes : 268
#
# Caracteristicas dos dados:
#
# O conjunto de dados contem apenas pacientes do sexo feminino (indios Pima), com 21 ou mais anos de idade
#
# Todos os atributos são numéricos
#
# Pode haver dados inválidos ou nulos
#
# atributos:
#
# pregnancies,	Glucose,	BloodPressure,	SkinThickness,	Insulin,	BMI,	DiabetesPedigreeFunction,	Age,	<b>Outcome</b>
#
# <b> Exemplos </b>
#
# 6,148,72,35,0,33.6,0.627,50,1
#
# 1,85,66,29,0,26.6,0.351,31,0
#
# <h2> Como funciona?</h2>
#
#   1. Treina com 80% dos casos dados, escolhidos aleatoriamente
#
#   2. Testa com os restantes 20% --> AVALIA (ESTATISTICAMENTE) SE O MODELO É CAPAZ DE DESCOBRIR NOVOS CASOS BEM
#
#   3. Se o modelo for bom, posso usá-lo
#
#   4. Dado um caso novo, medir as quantidades, formar um caso e submeter --> o sistema dá a sua previsão
#
#   caso novo: 3,154,71,55,0,31.6,0.638,40,<b>?</b>

# %% [raw]
# NOTA: vamos correr mocalmente, mas SE QUISER CORRER EM COLAB, TERÁ DE TER O SEGUINTE:
# import os
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# %matplotlib inline
#
#
# #dataset = pd.read_csv('pima-indians-diabetes.data.csv')
#
# from google.colab import files
# uploaded = files.upload()
#
# import io
# dataset = pd.read_csv(io.BytesIO(uploaded['pima-indians-diabetes.data.csv']))
# # Dataset is now stored in a Pandas Dataframe
#
# dataset.head(2)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('C:/Users/guibs/Documents/GitHub/SGD/Labs/lab8_class/data/pima-indians-diabetes.data.csv')

# %%
dataset.describe(include='all')
# Out:
#        Pregnancies     Glucose   BloodPressure   SkinThickness     Insulin  \
# count   768.000000  768.000000      768.000000      768.000000  768.000000
# mean      3.845052  120.894531       69.105469       20.536458   79.799479
# std       3.369578   31.972618       19.355807       15.952218  115.244002
# min       0.000000    0.000000        0.000000        0.000000    0.000000
# 25%       1.000000   99.000000       62.000000        0.000000    0.000000
# 50%       3.000000  117.000000       72.000000       23.000000   30.500000
# 75%       6.000000  140.250000       80.000000       32.000000  127.250000
# max      17.000000  199.000000      122.000000       99.000000  846.000000
#
#               BMI   DiabetesPedigreeFunction         Age       Class
# count  768.000000                 768.000000  768.000000  768.000000
# mean    31.992578                   0.471876   33.240885    0.348958
# std      7.884160                   0.331329   11.760232    0.476951
# min      0.000000                   0.078000   21.000000    0.000000
# 25%     27.300000                   0.243750   24.000000    0.000000
# 50%     32.000000                   0.372500   29.000000    0.000000
# 75%     36.600000                   0.626250   41.000000    1.000000
# max     67.100000                   2.420000   81.000000    1.000000

# %% [markdown]
# <h2> P1. Which two attributes have top correlation with class?</h2>
# Glocuse Level and BMI.
# <h2>P2. what two attributes have top correlation between them?</h2>
# Age and pregnancias are related because people tend to have children at a specific age interval
# Insulin and skin thickness

# %%
fig = plt.figure(figsize=(10, 8))
plt.rcParams['font.size'] = '16'
sns.heatmap(dataset.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2>P3. What does the next code do?</h2>
# Normalizar os dados

# %%
#standardizing the input feature
from sklearn.preprocessing import StandardScaler

X = dataset.iloc[:,0:8]
y = dataset.iloc[:,8]
sc = StandardScaler()

X = sc.fit_transform(X)
X
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %% [markdown]
# <h2>P4. WHat does the next code do? how big are train and test data?</h2>
# We split the dataset in training and testing data, we do this in the default sizes of 70/30 in order the test the model with new data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# <h2>O que faremos de seguida</h2>
# Pré-processámos os dados e agora estamos prontos para construir a rede neuronal.
#
# Estamos a usar keras para construir a rede neuronal. Importamos a biblioteca keras para criar as camadas de rede neuronal.
#
# Existem dois tipos principais de modelos disponíveis no keras - "Sequential" e "Model". usaremos o modelo "sequential" para construir nossa rede neuronal.
#
# Utilizamos a biblioteca "Dense" para criar camadas de entrada, oculta e saída de uma rede neuronal.

# %%
from keras import Sequential
from keras.layers import Dense

# %% [markdown]
# <h2>P5. Olhando para a figura da rede neuronal construida, preencha o que falta nos pontos seguintes </h2>
#
# <h3>(a) Temos 8 variáveis e uma variável objectivo (diabetes ou não).
#
# Teremos 2 camadas escondidas (hidden).
#
# Cada camada escondida terá 5 nós.
#
# Temos uma função de activação dos neuronios das camadas escondidas ReLu, a qual usará a função de activação sigmoide.
#
# Nota: uma camada "Dense" implementa a função: output = activation(dot(input, kernel) + bias)", sendo que dot é o produto e o kernel são os pesos mais o bias</h3>
#
# Keras oferece multiplos initializadores possiveis para o kernel (pesos)

# %% [markdown]
# ![alt text](C:\\Users\\guibs\\Documents\\GitHub\\SGD\\Labs\\lab8_class\\nn.png)

# %%
classifier = Sequential()

#First Hidden Layer
classifier.add(Dense(4, activation='relu', input_dim=8))
#Second  Hidden Layer
classifier.add(Dense(4, activation='relu'))
#Output Layer
classifier.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# Uma vez criadas as diferentes camadas, compilamos agora a rede neuronal.
#
# Como este é um problema de classificação binária, usamos binary_crossentropy para calcular a função de perda entre a saída real e a saída prevista.
#
# Para otimizar nossa rede neuronal, usamos Adam. Adam significa estimativa adaptativa do momento. Adam é uma combinação de RMSProp + Momentum.
#
# O momento leva em consideração os gradientes passados para suavizar a descida do gradiente.
#
# usamos métricas para medir o desempenho do modelo

# %%
#Compiling the neural network
import tensorflow as tf
classifier.compile(optimizer ='adam',loss='binary_crossentropy', metrics =['accuracy',tf.keras.metrics.Precision(),tf.keras.metrics.Recall()])

# %% [markdown]
# agora ajustamos os dados de treino ao modelo que criámos. usamos um batch_size de 10. Isso implica que usamos 10 amostras por atualização de gradiente.
#
# Iteramos mais de 100 épocas para treinar o modelo. Uma época é uma iteração em todo o conjunto de dados.
#
# <h2> P6. what's the "loss"? what do we want loss to be? what about "accuracy", "precision" and "recall"? is this a good result?</h2>
#
# Loss is a measurment of error, as the nn is trained the loss lowers, ideally it would be 0. Accurancy is the percentage of casses that were well classified. This is a reasonably a good model

# %%
#Fitting the data to the training dataset
classifier.fit(X_train,y_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 54/54 [==============================] - 0s 491us/step - loss: 0.7532 - accuracy: 0.4320 - precision_2: 0.3529 - recall_2: 0.6769
# Epoch 2/100
# 54/54 [==============================] - 0s 472us/step - loss: 0.6904 - accuracy: 0.5959 - precision_2: 0.4509 - recall_2: 0.5179
# Epoch 3/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.6649 - accuracy: 0.6760 - precision_2: 0.5695 - recall_2: 0.4410
# Epoch 4/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.6494 - accuracy: 0.6816 - precision_2: 0.6017 - recall_2: 0.3641
# Epoch 5/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.6382 - accuracy: 0.6909 - precision_2: 0.6283 - recall_2: 0.3641
# Epoch 6/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.6277 - accuracy: 0.6816 - precision_2: 0.6200 - recall_2: 0.3179
# Epoch 7/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.6176 - accuracy: 0.6927 - precision_2: 0.6500 - recall_2: 0.3333
# Epoch 8/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.6067 - accuracy: 0.7020 - precision_2: 0.6842 - recall_2: 0.3333
# Epoch 9/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.5958 - accuracy: 0.7132 - precision_2: 0.7158 - recall_2: 0.3487
# Epoch 10/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.5857 - accuracy: 0.7188 - precision_2: 0.7200 - recall_2: 0.3692
# Epoch 11/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.5737 - accuracy: 0.7263 - precision_2: 0.7222 - recall_2: 0.4000
# Epoch 12/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.5617 - accuracy: 0.7281 - precision_2: 0.7248 - recall_2: 0.4051
# Epoch 13/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.5504 - accuracy: 0.7356 - precision_2: 0.7304 - recall_2: 0.4308
# Epoch 14/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.5378 - accuracy: 0.7449 - precision_2: 0.7685 - recall_2: 0.4256
# Epoch 15/100
# 54/54 [==============================] - 0s 510us/step - loss: 0.5261 - accuracy: 0.7523 - precision_2: 0.7768 - recall_2: 0.4462
# Epoch 16/100
# 54/54 [==============================] - 0s 510us/step - loss: 0.5158 - accuracy: 0.7598 - precision_2: 0.7845 - recall_2: 0.4667
# Epoch 17/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.5057 - accuracy: 0.7635 - precision_2: 0.7787 - recall_2: 0.4872
# Epoch 18/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4968 - accuracy: 0.7672 - precision_2: 0.7869 - recall_2: 0.4923
# Epoch 19/100
# 54/54 [==============================] - 0s 567us/step - loss: 0.4891 - accuracy: 0.7784 - precision_2: 0.7923 - recall_2: 0.5282
# Epoch 20/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4823 - accuracy: 0.7765 - precision_2: 0.7698 - recall_2: 0.5487
# Epoch 21/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4762 - accuracy: 0.7803 - precision_2: 0.7770 - recall_2: 0.5538
# Epoch 22/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4705 - accuracy: 0.7840 - precision_2: 0.7762 - recall_2: 0.5692
# Epoch 23/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4664 - accuracy: 0.7803 - precision_2: 0.7730 - recall_2: 0.5590
# Epoch 24/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4626 - accuracy: 0.7840 - precision_2: 0.7651 - recall_2: 0.5846
# Epoch 25/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4591 - accuracy: 0.7840 - precision_2: 0.7724 - recall_2: 0.5744
# Epoch 26/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4554 - accuracy: 0.7877 - precision_2: 0.7718 - recall_2: 0.5897
# Epoch 27/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4522 - accuracy: 0.7858 - precision_2: 0.7667 - recall_2: 0.5897
# Epoch 28/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4496 - accuracy: 0.7858 - precision_2: 0.7597 - recall_2: 0.6000
# Epoch 29/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4473 - accuracy: 0.7896 - precision_2: 0.7662 - recall_2: 0.6051
# Epoch 30/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4452 - accuracy: 0.7896 - precision_2: 0.7662 - recall_2: 0.6051
# Epoch 31/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4426 - accuracy: 0.7933 - precision_2: 0.7727 - recall_2: 0.6103
# Epoch 32/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4413 - accuracy: 0.7933 - precision_2: 0.7658 - recall_2: 0.6205
# Epoch 33/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4393 - accuracy: 0.7952 - precision_2: 0.7707 - recall_2: 0.6205
# Epoch 34/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4377 - accuracy: 0.7989 - precision_2: 0.7771 - recall_2: 0.6256
# Epoch 35/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4370 - accuracy: 0.7933 - precision_2: 0.7658 - recall_2: 0.6205
# Epoch 36/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4350 - accuracy: 0.7952 - precision_2: 0.7673 - recall_2: 0.6256
# Epoch 37/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4333 - accuracy: 0.7952 - precision_2: 0.7673 - recall_2: 0.6256
# Epoch 38/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4325 - accuracy: 0.7952 - precision_2: 0.7673 - recall_2: 0.6256
# Epoch 39/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4319 - accuracy: 0.8007 - precision_2: 0.7821 - recall_2: 0.6256
# Epoch 40/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4305 - accuracy: 0.8026 - precision_2: 0.7730 - recall_2: 0.6462
# Epoch 41/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4293 - accuracy: 0.7989 - precision_2: 0.7669 - recall_2: 0.6410
# Epoch 42/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4290 - accuracy: 0.7970 - precision_2: 0.7622 - recall_2: 0.6410
# Epoch 43/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4276 - accuracy: 0.8007 - precision_2: 0.7716 - recall_2: 0.6410
# Epoch 44/100
# 54/54 [==============================] - 0s 567us/step - loss: 0.4268 - accuracy: 0.8007 - precision_2: 0.7683 - recall_2: 0.6462
# Epoch 45/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4262 - accuracy: 0.7970 - precision_2: 0.7622 - recall_2: 0.6410
# Epoch 46/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4253 - accuracy: 0.8007 - precision_2: 0.7651 - recall_2: 0.6513
# Epoch 47/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4248 - accuracy: 0.7989 - precision_2: 0.7636 - recall_2: 0.6462
# Epoch 48/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4247 - accuracy: 0.7989 - precision_2: 0.7636 - recall_2: 0.6462
# Epoch 49/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4237 - accuracy: 0.7989 - precision_2: 0.7636 - recall_2: 0.6462
# Epoch 50/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4223 - accuracy: 0.8007 - precision_2: 0.7651 - recall_2: 0.6513
# Epoch 51/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4219 - accuracy: 0.7989 - precision_2: 0.7636 - recall_2: 0.6462
# Epoch 52/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4215 - accuracy: 0.7970 - precision_2: 0.7622 - recall_2: 0.6410
# Epoch 53/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4207 - accuracy: 0.7989 - precision_2: 0.7605 - recall_2: 0.6513
# Epoch 54/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4204 - accuracy: 0.7952 - precision_2: 0.7576 - recall_2: 0.6410
# Epoch 55/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4196 - accuracy: 0.7952 - precision_2: 0.7485 - recall_2: 0.6564
# Epoch 56/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4191 - accuracy: 0.7970 - precision_2: 0.7590 - recall_2: 0.6462
# Epoch 57/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4188 - accuracy: 0.7970 - precision_2: 0.7560 - recall_2: 0.6513
# Epoch 58/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4186 - accuracy: 0.7970 - precision_2: 0.7560 - recall_2: 0.6513
# Epoch 59/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4176 - accuracy: 0.7952 - precision_2: 0.7485 - recall_2: 0.6564
# Epoch 60/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4170 - accuracy: 0.7970 - precision_2: 0.7529 - recall_2: 0.6564
# Epoch 61/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4171 - accuracy: 0.7933 - precision_2: 0.7471 - recall_2: 0.6513
# Epoch 62/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4161 - accuracy: 0.7952 - precision_2: 0.7485 - recall_2: 0.6564
# Epoch 63/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4159 - accuracy: 0.7970 - precision_2: 0.7471 - recall_2: 0.6667
# Epoch 64/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4150 - accuracy: 0.7933 - precision_2: 0.7471 - recall_2: 0.6513
# Epoch 65/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4151 - accuracy: 0.7970 - precision_2: 0.7500 - recall_2: 0.6615
# Epoch 66/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4147 - accuracy: 0.8026 - precision_2: 0.7486 - recall_2: 0.6872
# Epoch 67/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4142 - accuracy: 0.8026 - precision_2: 0.7459 - recall_2: 0.6923
# Epoch 68/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4144 - accuracy: 0.8007 - precision_2: 0.7529 - recall_2: 0.6718
# Epoch 69/100
# 54/54 [==============================] - 0s 567us/step - loss: 0.4143 - accuracy: 0.8007 - precision_2: 0.7500 - recall_2: 0.6769
# Epoch 70/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4132 - accuracy: 0.7989 - precision_2: 0.7458 - recall_2: 0.6769
# Epoch 71/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4134 - accuracy: 0.8063 - precision_2: 0.7514 - recall_2: 0.6974
# Epoch 72/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4129 - accuracy: 0.8063 - precision_2: 0.7486 - recall_2: 0.7026
# Epoch 73/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4128 - accuracy: 0.8026 - precision_2: 0.7459 - recall_2: 0.6923
# Epoch 74/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4124 - accuracy: 0.8026 - precision_2: 0.7486 - recall_2: 0.6872
# Epoch 75/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4118 - accuracy: 0.8045 - precision_2: 0.7500 - recall_2: 0.6923
# Epoch 76/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4114 - accuracy: 0.8007 - precision_2: 0.7444 - recall_2: 0.6872
# Epoch 77/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4119 - accuracy: 0.8026 - precision_2: 0.7459 - recall_2: 0.6923
# Epoch 78/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4115 - accuracy: 0.8082 - precision_2: 0.7527 - recall_2: 0.7026
# Epoch 79/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4114 - accuracy: 0.8063 - precision_2: 0.7486 - recall_2: 0.7026
# Epoch 80/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4108 - accuracy: 0.8063 - precision_2: 0.7486 - recall_2: 0.7026
# Epoch 81/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4111 - accuracy: 0.8007 - precision_2: 0.7472 - recall_2: 0.6821
# Epoch 82/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4104 - accuracy: 0.8045 - precision_2: 0.7473 - recall_2: 0.6974
# Epoch 83/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4108 - accuracy: 0.8045 - precision_2: 0.7473 - recall_2: 0.6974
# Epoch 84/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4104 - accuracy: 0.8063 - precision_2: 0.7486 - recall_2: 0.7026
# Epoch 85/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4101 - accuracy: 0.8045 - precision_2: 0.7473 - recall_2: 0.6974
# Epoch 86/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4098 - accuracy: 0.8045 - precision_2: 0.7446 - recall_2: 0.7026
# Epoch 87/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4094 - accuracy: 0.8045 - precision_2: 0.7473 - recall_2: 0.6974
# Epoch 88/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4091 - accuracy: 0.8007 - precision_2: 0.7391 - recall_2: 0.6974
# Epoch 89/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4086 - accuracy: 0.8026 - precision_2: 0.7459 - recall_2: 0.6923
# Epoch 90/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4091 - accuracy: 0.8045 - precision_2: 0.7446 - recall_2: 0.7026
# Epoch 91/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4088 - accuracy: 0.8026 - precision_2: 0.7405 - recall_2: 0.7026
# Epoch 92/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4084 - accuracy: 0.8045 - precision_2: 0.7419 - recall_2: 0.7077
# Epoch 93/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4083 - accuracy: 0.8026 - precision_2: 0.7405 - recall_2: 0.7026
# Epoch 94/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4088 - accuracy: 0.8007 - precision_2: 0.7391 - recall_2: 0.6974
# Epoch 95/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4079 - accuracy: 0.8007 - precision_2: 0.7391 - recall_2: 0.6974
# Epoch 96/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4078 - accuracy: 0.8045 - precision_2: 0.7419 - recall_2: 0.7077
# Epoch 97/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4075 - accuracy: 0.8063 - precision_2: 0.7459 - recall_2: 0.7077
# Epoch 98/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4081 - accuracy: 0.8045 - precision_2: 0.7446 - recall_2: 0.7026
# Epoch 99/100
# 54/54 [==============================] - 0s 548us/step - loss: 0.4076 - accuracy: 0.8026 - precision_2: 0.7405 - recall_2: 0.7026
# Epoch 100/100
# 54/54 [==============================] - 0s 529us/step - loss: 0.4077 - accuracy: 0.8026 - precision_2: 0.7405 - recall_2: 0.7026

# %% [markdown]
# <h2>P8. Is the comparison of results train/test the one you would expect? why?</h2>
# There's a little bit of a loss in the test data because the model is trained for the train data. however the loss isnt big so the model isn't over-fitted as it works well for the test data

# %%
eval_model=classifier.evaluate(X_train, y_train)
eval_model
# Out:
# 17/17 [==============================] - 0s 500us/step - loss: 0.4057 - accuracy: 0.8026 - precision_2: 0.7405 - recall_2: 0.7026
# [0.4056835472583771,
#  0.8026070594787598,
#  0.7405405640602112,
#  0.7025641202926636]

# %%
eval_model=classifier.evaluate(X_test, y_test)
eval_model
# Out:
# 8/8 [==============================] - 0s 572us/step - loss: 0.5527 - accuracy: 0.7273 - precision_2: 0.5556 - recall_2: 0.6849
# [0.5526806116104126,
#  0.7272727489471436,
#  0.5555555820465088,
#  0.6849315166473389]

# %% [markdown]
# ## Tell us if the first 5 estimations are correct? Why?
# For the first one, the real is 0 and the estimation was <0.00005
# The second one matches as well
# Third one matches
# 4 doesnt and 5fth does

# %%
y1_pred=classifier.predict(X_test)
y_pred =(y1_pred>0.5)

# %%
import numpy as np
y1_test = pd.DataFrame(y_test.values)
np.stack((y1_test.values,y1_pred),1)
# Out:
# array([[[0.00000000e+00],
#         [2.71783701e-05]],
#
#        [[1.00000000e+00],
#         [7.68739760e-01]],
#
#        [[1.00000000e+00],
#         [6.64911151e-01]],
#
#        [[0.00000000e+00],
#         [8.37875426e-01]],
#
#        [[0.00000000e+00],
#         [2.96020240e-01]],
#
#        [[0.00000000e+00],
#         [5.90134501e-01]],
#
#        [[1.00000000e+00],
#         [7.27389634e-01]],
#
#        [[0.00000000e+00],
#         [1.17685944e-01]],
#
#        [[1.00000000e+00],
#         [6.25457108e-01]],
#
#        [[1.00000000e+00],
#         [9.14805889e-01]],
#
#        [[1.00000000e+00],
#         [5.43447673e-01]],
#
#        [[0.00000000e+00],
#         [1.75302625e-02]],
#
#        [[0.00000000e+00],
#         [4.49180365e-01]],
#
#        [[1.00000000e+00],
#         [9.79005098e-02]],
#
#        [[1.00000000e+00],
#         [5.29493809e-01]],
#
#        [[0.00000000e+00],
#         [7.95876980e-03]],
#
#        [[1.00000000e+00],
#         [7.98725009e-01]],
#
#        [[0.00000000e+00],
#         [5.29924035e-03]],
#
#        [[0.00000000e+00],
#         [1.50214225e-01]],
#
#        [[0.00000000e+00],
#         [1.38868570e-01]],
#
#        [[1.00000000e+00],
#         [4.26714003e-01]],
#
#        [[0.00000000e+00],
#         [1.85272247e-01]],
#
#        [[0.00000000e+00],
#         [6.34530485e-02]],
#
#        [[0.00000000e+00],
#         [6.17989421e-01]],
#
#        [[0.00000000e+00],
#         [7.56804347e-01]],
#
#        [[0.00000000e+00],
#         [4.20804322e-02]],
#
#        [[0.00000000e+00],
#         [7.82986879e-01]],
#
#        [[0.00000000e+00],
#         [1.15645051e-01]],
#
#        [[1.00000000e+00],
#         [3.30397487e-03]],
#
#        [[0.00000000e+00],
#         [1.41799450e-04]],
#
#        [[0.00000000e+00],
#         [6.35956228e-02]],
#
#        [[0.00000000e+00],
#         [4.92607057e-02]],
#
#        [[0.00000000e+00],
#         [7.49108195e-01]],
#
#        [[1.00000000e+00],
#         [8.65115523e-01]],
#
#        [[0.00000000e+00],
#         [5.07214546e-01]],
#
#        [[0.00000000e+00],
#         [4.96958166e-01]],
#
#        [[0.00000000e+00],
#         [2.85419196e-01]],
#
#        [[0.00000000e+00],
#         [5.46697736e-01]],
#
#        [[0.00000000e+00],
#         [5.32978773e-03]],
#
#        [[0.00000000e+00],
#         [1.15691125e-02]],
#
#        [[0.00000000e+00],
#         [9.03717875e-01]],
#
#        [[1.00000000e+00],
#         [9.09302592e-01]],
#
#        [[0.00000000e+00],
#         [7.54440129e-02]],
#
#        [[1.00000000e+00],
#         [3.35167646e-01]],
#
#        [[0.00000000e+00],
#         [2.00015008e-02]],
#
#        [[0.00000000e+00],
#         [5.77285886e-01]],
#
#        [[0.00000000e+00],
#         [4.34872508e-03]],
#
#        [[0.00000000e+00],
#         [1.99806690e-03]],
#
#        [[0.00000000e+00],
#         [5.24318755e-01]],
#
#        [[0.00000000e+00],
#         [4.66070771e-02]],
#
#        [[0.00000000e+00],
#         [1.04904175e-03]],
#
#        [[1.00000000e+00],
#         [5.21693826e-01]],
#
#        [[0.00000000e+00],
#         [2.37787366e-02]],
#
#        [[0.00000000e+00],
#         [8.17968488e-01]],
#
#        [[1.00000000e+00],
#         [7.00475574e-02]],
#
#        [[0.00000000e+00],
#         [2.95197070e-02]],
#
#        [[1.00000000e+00],
#         [1.08268470e-01]],
#
#        [[1.00000000e+00],
#         [5.39838374e-01]],
#
#        [[0.00000000e+00],
#         [6.89226508e-01]],
#
#        [[1.00000000e+00],
#         [6.73565269e-01]],
#
#        [[0.00000000e+00],
#         [5.07214546e-01]],
#
#        [[1.00000000e+00],
#         [4.46662068e-01]],
#
#        [[0.00000000e+00],
#         [5.58347762e-01]],
#
#        [[1.00000000e+00],
#         [9.05436039e-01]],
#
#        [[1.00000000e+00],
#         [6.70380414e-01]],
#
#        [[0.00000000e+00],
#         [5.40048718e-01]],
#
#        [[0.00000000e+00],
#         [6.17142975e-01]],
#
#        [[0.00000000e+00],
#         [3.38228643e-01]],
#
#        [[0.00000000e+00],
#         [2.48950243e-01]],
#
#        [[1.00000000e+00],
#         [8.19909573e-03]],
#
#        [[0.00000000e+00],
#         [1.50873005e-01]],
#
#        [[1.00000000e+00],
#         [5.67559302e-01]],
#
#        [[0.00000000e+00],
#         [1.42170191e-02]],
#
#        [[0.00000000e+00],
#         [1.69201493e-02]],
#
#        [[0.00000000e+00],
#         [6.97995305e-01]],
#
#        [[1.00000000e+00],
#         [3.22584122e-01]],
#
#        [[1.00000000e+00],
#         [8.36851358e-01]],
#
#        [[0.00000000e+00],
#         [1.22040480e-01]],
#
#        [[0.00000000e+00],
#         [1.10217929e-03]],
#
#        [[0.00000000e+00],
#         [1.23585552e-01]],
#
#        [[1.00000000e+00],
#         [5.64243138e-01]],
#
#        [[1.00000000e+00],
#         [1.02502525e-01]],
#
#        [[0.00000000e+00],
#         [9.23928618e-03]],
#
#        [[0.00000000e+00],
#         [5.13373375e-01]],
#
#        [[1.00000000e+00],
#         [8.87838006e-01]],
#
#        [[0.00000000e+00],
#         [2.99771070e-01]],
#
#        [[0.00000000e+00],
#         [3.25661004e-02]],
#
#        [[0.00000000e+00],
#         [2.05347210e-01]],
#
#        [[0.00000000e+00],
#         [2.36317992e-01]],
#
#        [[0.00000000e+00],
#         [1.13724023e-01]],
#
#        [[1.00000000e+00],
#         [6.49858415e-02]],
#
#        [[0.00000000e+00],
#         [1.23680711e-01]],
#
#        [[0.00000000e+00],
#         [5.35750985e-02]],
#
#        [[1.00000000e+00],
#         [7.86845207e-01]],
#
#        [[0.00000000e+00],
#         [9.15625691e-02]],
#
#        [[1.00000000e+00],
#         [5.50431192e-01]],
#
#        [[1.00000000e+00],
#         [7.86388040e-01]],
#
#        [[0.00000000e+00],
#         [8.08003545e-03]],
#
#        [[0.00000000e+00],
#         [1.12468004e-02]],
#
#        [[1.00000000e+00],
#         [9.25120175e-01]],
#
#        [[1.00000000e+00],
#         [8.12780976e-01]],
#
#        [[0.00000000e+00],
#         [1.53859854e-02]],
#
#        [[1.00000000e+00],
#         [2.62385160e-01]],
#
#        [[0.00000000e+00],
#         [2.19219804e-01]],
#
#        [[0.00000000e+00],
#         [4.67237055e-01]],
#
#        [[0.00000000e+00],
#         [1.77173972e-01]],
#
#        [[0.00000000e+00],
#         [2.56051719e-02]],
#
#        [[0.00000000e+00],
#         [8.35674047e-01]],
#
#        [[1.00000000e+00],
#         [3.69700670e-01]],
#
#        [[0.00000000e+00],
#         [3.42884511e-01]],
#
#        [[1.00000000e+00],
#         [6.84206307e-01]],
#
#        [[1.00000000e+00],
#         [7.82897472e-01]],
#
#        [[0.00000000e+00],
#         [4.12601918e-01]],
#
#        [[0.00000000e+00],
#         [2.11235881e-03]],
#
#        [[0.00000000e+00],
#         [9.01732266e-01]],
#
#        [[0.00000000e+00],
#         [1.82871759e-01]],
#
#        [[0.00000000e+00],
#         [3.16199912e-05]],
#
#        [[0.00000000e+00],
#         [5.54881334e-01]],
#
#        [[0.00000000e+00],
#         [1.38574243e-02]],
#
#        [[0.00000000e+00],
#         [1.58428550e-02]],
#
#        [[0.00000000e+00],
#         [1.79455578e-02]],
#
#        [[0.00000000e+00],
#         [1.59169436e-02]],
#
#        [[1.00000000e+00],
#         [9.74793613e-01]],
#
#        [[0.00000000e+00],
#         [4.89216655e-01]],
#
#        [[0.00000000e+00],
#         [7.30156898e-03]],
#
#        [[0.00000000e+00],
#         [2.97970057e-01]],
#
#        [[0.00000000e+00],
#         [1.33195817e-02]],
#
#        [[0.00000000e+00],
#         [5.59551656e-01]],
#
#        [[0.00000000e+00],
#         [2.12633252e-01]],
#
#        [[0.00000000e+00],
#         [7.32177734e-01]],
#
#        [[0.00000000e+00],
#         [2.70753235e-01]],
#
#        [[0.00000000e+00],
#         [4.95326251e-01]],
#
#        [[1.00000000e+00],
#         [5.25818229e-01]],
#
#        [[0.00000000e+00],
#         [1.27440989e-02]],
#
#        [[0.00000000e+00],
#         [6.82804883e-02]],
#
#        [[0.00000000e+00],
#         [1.27114117e-01]],
#
#        [[0.00000000e+00],
#         [5.21475971e-01]],
#
#        [[0.00000000e+00],
#         [1.96325421e-01]],
#
#        [[0.00000000e+00],
#         [1.31305873e-01]],
#
#        [[0.00000000e+00],
#         [2.10707575e-01]],
#
#        [[0.00000000e+00],
#         [9.15739238e-01]],
#
#        [[0.00000000e+00],
#         [3.10901403e-02]],
#
#        [[0.00000000e+00],
#         [6.03673697e-01]],
#
#        [[0.00000000e+00],
#         [1.47366226e-02]],
#
#        [[0.00000000e+00],
#         [9.45110023e-02]],
#
#        [[1.00000000e+00],
#         [4.05832231e-02]],
#
#        [[0.00000000e+00],
#         [1.28546923e-01]],
#
#        [[0.00000000e+00],
#         [5.17262697e-01]],
#
#        [[0.00000000e+00],
#         [2.98368931e-02]],
#
#        [[0.00000000e+00],
#         [8.34744930e-01]],
#
#        [[0.00000000e+00],
#         [3.67230237e-01]],
#
#        [[1.00000000e+00],
#         [2.95160115e-01]],
#
#        [[0.00000000e+00],
#         [3.27699780e-02]],
#
#        [[0.00000000e+00],
#         [8.66261244e-01]],
#
#        [[0.00000000e+00],
#         [2.80191481e-01]],
#
#        [[0.00000000e+00],
#         [7.38800882e-05]],
#
#        [[0.00000000e+00],
#         [3.39652658e-01]],
#
#        [[0.00000000e+00],
#         [4.14324522e-01]],
#
#        [[1.00000000e+00],
#         [3.90529782e-01]],
#
#        [[1.00000000e+00],
#         [8.26545954e-01]],
#
#        [[0.00000000e+00],
#         [6.28955841e-01]],
#
#        [[0.00000000e+00],
#         [8.99133086e-03]],
#
#        [[0.00000000e+00],
#         [4.84926134e-01]],
#
#        [[0.00000000e+00],
#         [7.89472461e-02]],
#
#        [[1.00000000e+00],
#         [1.60982013e-01]],
#
#        [[0.00000000e+00],
#         [3.15977633e-02]],
#
#        [[0.00000000e+00],
#         [8.89099240e-02]],
#
#        [[0.00000000e+00],
#         [5.64455628e-01]],
#
#        [[1.00000000e+00],
#         [9.36035454e-01]],
#
#        [[0.00000000e+00],
#         [9.74304676e-02]],
#
#        [[0.00000000e+00],
#         [9.81645584e-02]],
#
#        [[1.00000000e+00],
#         [1.07698143e-02]],
#
#        [[1.00000000e+00],
#         [7.74595022e-01]],
#
#        [[0.00000000e+00],
#         [5.02993286e-01]],
#
#        [[1.00000000e+00],
#         [4.13758516e-01]],
#
#        [[0.00000000e+00],
#         [8.73100758e-03]],
#
#        [[0.00000000e+00],
#         [4.10644203e-01]],
#
#        [[1.00000000e+00],
#         [6.03970945e-01]],
#
#        [[0.00000000e+00],
#         [1.75460607e-01]],
#
#        [[0.00000000e+00],
#         [2.80199826e-01]],
#
#        [[0.00000000e+00],
#         [3.33293021e-01]],
#
#        [[1.00000000e+00],
#         [7.90508509e-01]],
#
#        [[1.00000000e+00],
#         [6.57055259e-01]],
#
#        [[0.00000000e+00],
#         [2.42810637e-01]],
#
#        [[1.00000000e+00],
#         [7.76646197e-01]],
#
#        [[1.00000000e+00],
#         [7.81625271e-01]],
#
#        [[0.00000000e+00],
#         [5.17502904e-01]],
#
#        [[0.00000000e+00],
#         [7.43898749e-03]],
#
#        [[1.00000000e+00],
#         [8.42587829e-01]],
#
#        [[1.00000000e+00],
#         [3.91619831e-01]],
#
#        [[1.00000000e+00],
#         [6.28181577e-01]],
#
#        [[1.00000000e+00],
#         [3.24115902e-01]],
#
#        [[0.00000000e+00],
#         [1.54882371e-02]],
#
#        [[0.00000000e+00],
#         [4.29397821e-03]],
#
#        [[0.00000000e+00],
#         [3.20355594e-02]],
#
#        [[0.00000000e+00],
#         [4.37235534e-02]],
#
#        [[1.00000000e+00],
#         [8.49745750e-01]],
#
#        [[0.00000000e+00],
#         [5.18116951e-02]],
#
#        [[1.00000000e+00],
#         [2.16487885e-01]],
#
#        [[0.00000000e+00],
#         [5.37694991e-01]],
#
#        [[1.00000000e+00],
#         [6.35920644e-01]],
#
#        [[0.00000000e+00],
#         [2.26671815e-01]],
#
#        [[1.00000000e+00],
#         [7.78944790e-01]],
#
#        [[1.00000000e+00],
#         [7.95054436e-01]],
#
#        [[0.00000000e+00],
#         [6.66994452e-01]],
#
#        [[0.00000000e+00],
#         [7.80701637e-04]],
#
#        [[1.00000000e+00],
#         [5.11178374e-01]],
#
#        [[0.00000000e+00],
#         [9.62442160e-02]],
#
#        [[1.00000000e+00],
#         [2.62597710e-01]],
#
#        [[0.00000000e+00],
#         [6.46790862e-01]],
#
#        [[1.00000000e+00],
#         [5.68605542e-01]],
#
#        [[1.00000000e+00],
#         [9.96556520e-01]],
#
#        [[0.00000000e+00],
#         [7.95954466e-03]],
#
#        [[0.00000000e+00],
#         [6.57681525e-02]],
#
#        [[0.00000000e+00],
#         [3.08618844e-01]],
#
#        [[1.00000000e+00],
#         [8.42034101e-01]],
#
#        [[1.00000000e+00],
#         [8.17095518e-01]],
#
#        [[1.00000000e+00],
#         [6.87425435e-01]],
#
#        [[0.00000000e+00],
#         [7.71373272e-01]],
#
#        [[0.00000000e+00],
#         [1.78561211e-02]],
#
#        [[0.00000000e+00],
#         [6.33385360e-01]],
#
#        [[0.00000000e+00],
#         [3.94213200e-02]],
#
#        [[0.00000000e+00],
#         [4.68659401e-03]],
#
#        [[0.00000000e+00],
#         [1.44624233e-01]],
#
#        [[0.00000000e+00],
#         [1.14033252e-01]],
#
#        [[0.00000000e+00],
#         [6.89528286e-01]],
#
#        [[0.00000000e+00],
#         [1.09544218e-01]],
#
#        [[0.00000000e+00],
#         [2.47946411e-01]],
#
#        [[1.00000000e+00],
#         [7.42039084e-01]],
#
#        [[1.00000000e+00],
#         [5.48041463e-01]],
#
#        [[0.00000000e+00],
#         [8.36231112e-02]]])

# %% [markdown]
# <h2> P11. What does the next matrix tell us?</h2>
# 40 false positives
# 39 false negatives

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[118  40]
#  [ 23  50]]

# %% [markdown]
# C:\Users\guibs\Documents\GitHub\SGD\Labs\lab8_class# THE END

# %% [markdown]
# <h1>Algumas respostas</h1>
# Temos 8 variáveis e uma variável objectivo (diabetes ou não).
#
# Teremos duas camadas escondidas (hidden).
#
# Cada camada escondida terá 4 nós.
#
# Temos uma função de activação dos neuronios das camadas escondidas ReLu, a qual usará a função de activação sigmoide
#
# "Dense layer implements output = activation(dot(input, kernel) + bias)"
#
#
# Keras oferece multiplos initializadores possiveis
#
# Nota: uma camada "Dense" implementa a função: output = activation(dot(input, kernel) + bias)", sendo que dot é o produto e o kernel são pesos
#
# Keras oferece multiplos initializadores possiveis para o kernel (pesos)
